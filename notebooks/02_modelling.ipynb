# %% [markdown]
# ### 1.0. Setup project path

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0]
sys.path.append(str(PROJECT_ROOT))

# %% [markdown]
# ### 2.0. Train

# %%
# !python ../src/train.py
# Out:
# Saved model to: /home/luisparadinha/posgrad/bi2_bmw_car_price/models/xgb_fair_price.joblib
# MAE: 1513.6798095703125
# RMSE: 2618.4140237937927

# %% [markdown]
# ### 3.0. Predict Deals

# %%
# !python ../src/predict.py
# Out:
# Wrote deals to: /home/luisparadinha/posgrad/bi2_bmw_car_price/reports/market_value.csv
# Top 10 deals:
#        price  market_value
# 3638  123456  88655.382812
# 1813   88980  88615.835938
# 4776   89900  86379.906250
# 721    84898  84088.257812
# 5877   81140  80963.593750
# 6115   79991  80032.656250
# 7024   79566  78437.531250
# 241    78000  77188.046875
# 1704   76970  77185.742188
# 7112   77995  77110.945312

# %% [markdown]
# ### 4.0. View metrics + top deals

# %%
import json
import pandas as pd
from src.config import REPORTS_DIR

with open(REPORTS_DIR / "metrics.json", "r") as f:
    metrics = json.load(f)

metrics
# Out:
# {'mae': 1513.6798095703125,
#  'rmse': 2618.4140237937927,
#  'n_rows': 10781,
#  'n_features': 8,
#  'numeric_cols': ['year', 'mileage', 'tax', 'mpg', 'engineSize'],
#  'categorical_cols': ['model', 'transmission', 'fuelType'],
#  'model_path': '/home/luisparadinha/posgrad/bi2_bmw_car_price/models/xgb_fair_price.joblib'}

# %% [markdown]
# ### 5.0. Load and inspect deals.csv

# %%
df = pd.read_csv(REPORTS_DIR / "market_value.csv")

# Show the best "deals" first
df.head(20)
# Out:
#         model  year   price transmission  mileage fuelType  tax   mpg  \
# 0    2 Series  2015  123456    Semi-Auto    33419   Diesel   20  68.9
# 1    8 Series  2019   88980    Semi-Auto       88   Petrol  145  24.4
# 2          M5  2019   89900    Semi-Auto     2269   Petrol  145  24.1
# 3    8 Series  2019   84898    Semi-Auto     3185   Petrol  145  24.4
# 4          M5  2019   81140    Semi-Auto      551   Petrol  145  24.1
# 5    8 Series  2020   79991    Semi-Auto      151   Diesel  145  26.7
# 6          X7  2020   79566    Semi-Auto     1000   Petrol  145  24.8
# 7          X7  2020   78000    Semi-Auto     5000   Diesel  150  31.4
# 8          X7  2019   76970    Semi-Auto       10   Diesel  145  31.4
# 9          X7  2020   77995    Semi-Auto     7500   Diesel  150  31.4
# 10         X7  2020   77990    Semi-Auto     5656   Diesel  150  31.4
# 11         X7  2019   77880    Semi-Auto     6506   Diesel  150  31.4
# 12         X7  2019   77880    Semi-Auto     6506   Diesel  145  31.4
# 13         X7  2019   78386    Automatic     1793   Diesel  145  31.4
# 14         M5  2019   74988    Automatic     2684   Petrol  145  24.1
# 15         M4  2016   76990    Automatic     4550   Petrol  300  33.2
# 16         X7  2019   73990    Semi-Auto     1657   Diesel  145  31.4
# 17         M5  2019   73990    Automatic     1501   Petrol  145  24.1
# 18         X7  2020   71980    Semi-Auto     8695   Diesel  150  31.4
# 19         X7  2019   74990    Semi-Auto     9200   Diesel  145  31.4
#
#     engineSize  market_value
# 0          2.0     88655.380
# 1          4.4     88615.836
# 2          4.4     86379.910
# 3          4.4     84088.260
# 4          4.4     80963.590
# 5          3.0     80032.660
# 6          3.0     78437.530
# 7          3.0     77188.050
# 8          3.0     77185.740
# 9          3.0     77110.945
# 10         3.0     76778.000
# 11         3.0     76305.850
# 12         3.0     75801.125
# 13         3.0     75235.805
# 14         4.4     74849.805
# 15         3.0     74848.170
# 16         3.0     74263.730
# 17         4.4     74251.260
# 18         3.0     74146.870
# 19         3.0     74109.336
